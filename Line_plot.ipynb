# %% [markdown]
# <a href="https://colab.research.google.com/github/imsaddam/Data-visualization-by-Python/blob/master/Line_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import matplotlib.pyplot library
import matplotlib.pyplot as plt

#take two variables years and population and store some value
years = [1950,1970,1990,2010]
population = [2.519,3.692,5.265,6.994]

plt.xlabel('Years')
plt.ylabel('Number of Population [in billions]')
plt.title('World Population Example')

#plot a straight line 
plt.plot(years, population)
plt.show()

plt.xlabel('Years')
plt.ylabel('Number of Population [in billions]')
plt.title('World Population Example')

#plot scatter type line
plt.scatter(years, population)
plt.show()
